# %% [markdown]
# <a href="https://colab.research.google.com/github/iremyuvali/ml-tasks/blob/main/task3_iremyuvali.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
#  **iremyuvali | 2017555071**

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.datasets import load_iris
from sklearn.model_selection import train_test_split
from sklearn.naive_bayes import GaussianNB
from sklearn.linear_model import LinearRegression
from sklearn.metrics import classification_report
from sklearn.metrics import confusion_matrix
from sklearn.metrics import accuracy_score
from sklearn.metrics import mean_absolute_error,mean_squared_error

# %%
iris = load_iris()
iris.data
# Out:
# array([[5.1, 3.5, 1.4, 0.2],
#        [4.9, 3. , 1.4, 0.2],
#        [4.7, 3.2, 1.3, 0.2],
#        [4.6, 3.1, 1.5, 0.2],
#        [5. , 3.6, 1.4, 0.2],
#        [5.4, 3.9, 1.7, 0.4],
#        [4.6, 3.4, 1.4, 0.3],
#        [5. , 3.4, 1.5, 0.2],
#        [4.4, 2.9, 1.4, 0.2],
#        [4.9, 3.1, 1.5, 0.1],
#        [5.4, 3.7, 1.5, 0.2],
#        [4.8, 3.4, 1.6, 0.2],
#        [4.8, 3. , 1.4, 0.1],
#        [4.3, 3. , 1.1, 0.1],
#        [5.8, 4. , 1.2, 0.2],
#        [5.7, 4.4, 1.5, 0.4],
#        [5.4, 3.9, 1.3, 0.4],
#        [5.1, 3.5, 1.4, 0.3],
#        [5.7, 3.8, 1.7, 0.3],
#        [5.1, 3.8, 1.5, 0.3],
#        [5.4, 3.4, 1.7, 0.2],
#        [5.1, 3.7, 1.5, 0.4],
#        [4.6, 3.6, 1. , 0.2],
#        [5.1, 3.3, 1.7, 0.5],
#        [4.8, 3.4, 1.9, 0.2],
#        [5. , 3. , 1.6, 0.2],
#        [5. , 3.4, 1.6, 0.4],
#        [5.2, 3.5, 1.5, 0.2],
#        [5.2, 3.4, 1.4, 0.2],
#        [4.7, 3.2, 1.6, 0.2],
#        [4.8, 3.1, 1.6, 0.2],
#        [5.4, 3.4, 1.5, 0.4],
# ...

# %%
iris_data=pd.DataFrame(iris.data, columns=iris.feature_names)
iris_data
# Out:
#      sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)
# 0                  5.1               3.5                1.4               0.2
# 1                  4.9               3.0                1.4               0.2
# 2                  4.7               3.2                1.3               0.2
# 3                  4.6               3.1                1.5               0.2
# 4                  5.0               3.6                1.4               0.2
# ..                 ...               ...                ...               ...
# 145                6.7               3.0                5.2               2.3
# 146                6.3               2.5                5.0               1.9
# 147                6.5               3.0                5.2               2.0
# 148                6.2               3.4                5.4               2.3
# 149                5.9               3.0                5.1               1.8
#
# [150 rows x 4 columns]

# %%
iris_data.describe()
# Out:
#        sepal length (cm)  sepal width (cm)  petal length (cm)  \
# count         150.000000        150.000000         150.000000
# mean            5.843333          3.057333           3.758000
# std             0.828066          0.435866           1.765298
# min             4.300000          2.000000           1.000000
# 25%             5.100000          2.800000           1.600000
# 50%             5.800000          3.000000           4.350000
# 75%             6.400000          3.300000           5.100000
# max             7.900000          4.400000           6.900000
#
#        petal width (cm)
# count        150.000000
# mean           1.199333
# std            0.762238
# min            0.100000
# 25%            0.300000
# 50%            1.300000
# 75%            1.800000
# max            2.500000

# %%
x, y = iris.data, iris.target

iris.target_names
# Out:
# array(['setosa', 'versicolor', 'virginica'], dtype='<U10')

# %%
plt.scatter(x[:,0],x[:,1])
plt.title("the iris data")
plt.show()

# %%
plt.scatter(x[:,0],x[:,1],c=y)
plt.title("the target data")
plt.show()

# %%
x_train, x_test, y_train, y_test = train_test_split(x,y, random_state=50)

# %%
plt.scatter(x_train[:,0],x_train[:,1],c=y_train)
plt.title("train")
plt.show()

# %%
plt.scatter(x_test[:,0],x_test[:,1],c=y_test)
plt.title("test")
plt.show()

# %%
naive_bayes = GaussianNB()
naive_bayes.fit(x_train,y_train)

y_pred = naive_bayes.predict(x_test)

print(classification_report(y_test,y_pred))
print(confusion_matrix(y_test,y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00        11
#            1       0.93      0.93      0.93        15
#            2       0.92      0.92      0.92        12
#
#     accuracy                           0.95        38
#    macro avg       0.95      0.95      0.95        38
# weighted avg       0.95      0.95      0.95        38
#
# [[11  0  0]
#  [ 0 14  1]
#  [ 0  1 11]]

# %%
print(accuracy_score(y_test,y_pred))
# Out:
# 0.9473684210526315

# %%
df_lin= pd.DataFrame({'Actual': y_test, 'Predicted': y_pred})
df_lin
# Out:
#     Actual  Predicted
# 0        1          1
# 1        1          1
# 2        0          0
# 3        0          0
# 4        2          2
# 5        2          2
# 6        2          2
# 7        0          0
# 8        0          0
# 9        1          1
# 10       0          0
# 11       2          2
# 12       0          0
# 13       2          2
# 14       1          1
# 15       0          0
# 16       1          1
# 17       0          0
# 18       1          1
# 19       1          2
# 20       2          2
# 21       1          1
# 22       0          0
# 23       2          2
# 24       1          1
# 25       2          2
# 26       1          1
# 27       1          1
# 28       1          1
# 29       2          2
# 30       2          2
# 31       1          1
# 32       1          1
# 33       2          2
# 34       0          0
# 35       0          0
# 36       1          1
# 37       2          1

# %% [markdown]
# # **Linear Regression**

# %%
lin_reg=LinearRegression()
lin_reg.fit(x_train,y_train)

LinearRegression(copy_X=True, fit_intercept=True, n_jobs=1, normalize=False)

y_pred=lin_reg.predict(x_test)
y_pred

print('Mean Absolute Error:', mean_absolute_error(y_test, y_pred))
print('Mean Squared Error:', mean_squared_error(y_test, y_pred))
# Out:
# Mean Absolute Error: 0.18566922531807886
# Mean Squared Error: 0.05296438464612992

# %%
df_lin= pd.DataFrame({'Actual': y_test, 'Predicted': y_pred})
df_lin
# Out:
#     Actual  Predicted
# 0        1   1.187401
# 1        1   1.441487
# 2        0  -0.047857
# 3        0  -0.038141
# 4        2   1.775878
# 5        2   2.091058
# 6        2   1.848876
# 7        0   0.181692
# 8        0  -0.088820
# 9        1   1.379188
# 10       0  -0.058733
# 11       2   1.823419
# 12       0  -0.019767
# 13       2   1.872583
# 14       1   1.276781
# 15       0  -0.003233
# 16       1   1.072627
# 17       0  -0.097700
# 18       1   0.951295
# 19       1   1.518151
# 20       2   2.278919
# 21       1   1.037123
# 22       0  -0.238172
# 23       2   1.843243
# 24       1   1.318601
# 25       2   2.233395
# 26       1   1.416556
# 27       1   1.335091
# 28       1   1.169617
# 29       2   2.078361
# 30       2   1.738642
# 31       1   0.897330
# 32       1   1.212947
# 33       2   2.166054
# 34       0   0.051722
# 35       0   0.014309
# 36       1   1.267483
# 37       2   1.514289

# %%
lin_reg.coef_
# Out:
# array([-0.11358782, -0.05416297,  0.22476593,  0.63351931])

# %%
lin_reg.intercept_
# Out:
# 0.24086588657301933
